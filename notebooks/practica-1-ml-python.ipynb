# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/echocardiogram3/echocardiogram.names
# /kaggle/input/echocardiogram3/echocardiogram.data

# %% [markdown]
# # Introduccion de Python a Machine Learning

# %% [markdown]
# (a) Create an array of 10 random integers between 1 and 100, and then calculate the mean and standard deviation of the array.

# %%
#Create an array of 10 random integers between 1 and 100.
a = [23,34,45,12,45,3,56,21,56,87]
print(a)
b = np.random.randint(1,high=101,size=10)
print(b)
#calculate the mean. standard deviation of the array.
print(b.mean())
print(np.mean(a))
#calculate the standard deviation of the array.
print(b.std())
print(np.std(a))
# Out:
# [23, 34, 45, 12, 45, 3, 56, 21, 56, 87]
# [92 68 42 82 38 47 35 23 12 18]
# 45.7
# 38.2
# 25.62440243205683
# 23.61694307060082

# %% [markdown]
# (b) Create a 2-dimensional array of 3 rows and 4 columns with random integer values. Then, calculate the sum of each row and column.

# %%
#Create a 2-dimensional array with random integer values
array = np.random.randint(low=1, high=10, size=(3, 4))
print(array)

#Calculate the sum of each row
filas = np.sum(array, axis=1)

#Calculate the sum of each column
columnas = np.sum(array, axis=0)

print("Suma de filas:")
print(filas)

print("Suma de columnas:")
print(columnas)
# Out:
# [[8 1 7 3]
#  [2 9 3 5]
#  [8 9 9 9]]
# Suma de filas:
# [19 19 35]
# Suma de columnas:
# [18 19 19 17]

# %% [markdown]
# (c) Create a DataFrame with 3 columns: "Name", "Age", and "City". Add at least 5 rows of data to the
# DataFrame. Then, filter the DataFrame to only include rows where the person's age is greater than
# or equal to 30.

# %%
#Crear un diccionario con 3 columnas: "Name", "Age", and "City"
data = {
    'Name': ['Juana', 'Veronica', 'Adriana', 'Julian', 'Esteban'],
    'Age': [25, 32, 29, 35, 27],
    'City': ['Quito', 'Barcelona', 'Cuenca', 'Guayaquil', 'Puyo']
}

#Convertir el diccionario a dataframe
df = pd.DataFrame(data)

#Filtar los datos segun la edad mayor o igual a 30
df_age = df[df['Age'] >= 30]

#Imprimir el resultado
print(df_age)
# Out:
#        Name  Age       City
# 1  Veronica   32  Barcelona
# 3    Julian   35  Guayaquil

# %% [markdown]
# (d) Load a CSV file into a DataFrame and then calculate the mean, median, and mode of one of the
# columns in the DataFrame.

# %%
exam_scores = pd.read_csv('/kaggle/input/students-exam-scores/Expanded_data_with_more_features.csv', delimiter=',')
exam_scores
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
#La media, mediana, y moda de la columna "MathScore"

# Calcular la media de la columna
media = exam_scores['MathScore'].mean()

# Calcular la mediana de la columna
mediana = exam_scores['MathScore'].median()

# Calcular la moda de la columna
moda = exam_scores['MathScore'].mode().iloc[0]

# Mostrar los resultados
print("Media:", media)
print("Mediana:", mediana)
print("Moda:", moda)
# Out:
# Media: 66.5584021409223
# Mediana: 67.0
# Moda: 64

# %% [markdown]
# (e) Create a scatter plot of random x and y values between 1 and 100.

# %%
#Importar la libreria nesesaria para hacer los graficos
import matplotlib.pyplot as plt

# %%
#Generar valores aleatorios para x, y
x = np.random.randint(1, 101, size=50)
y = np.random.randint(1, 101, size=50)

#Crear el gráfico de dispersión
plt.scatter(x, y)

#Definir el titulo y los nombres de cada eje
plt.title("Gráfico de dispersión Aleatorio")
plt.xlabel("X")
plt.ylabel("Y")

#Imprimir el grafico
plt.show()

# %% [markdown]
# (f) Load a CSV file into a DataFrame and then create a line chart of one of the columns in the
# DataFrame.

# %%
# Plot the line chart
plt.plot(exam_scores['Unnamed: 0'], exam_scores['MathScore'])

# Customize the chart
plt.title('Line Chart of {}'.format('MathScore'))
plt.xlabel('Unnamed: 0')
plt.ylabel('MathScore')

# Show the chart
plt.show()

# %% [markdown]
# # 3. Data Import

# %% [markdown]
# (a) Download the Echocardiogram data set and import it to a data frame. Read the information on the
# data set and find out how missing values are represented and make sure that they are properly
# represented.

# %%
dataframe = pd.read_csv('/kaggle/input/echocardiogram3/echocardiogram.data', delimiter=',')
dataframe
# Out:
#       11  0  71  0.1  0.260       9  4.600    14      1    1.1  name 1.2 0.2
# 0     19  0  72    0  0.380       6  4.100    14  1.700  0.588  name   1   0
# 1     16  0  55    0  0.260       4  3.420    14      1      1  name   1   0
# 2     57  0  60    0  0.253  12.062  4.603    16  1.450  0.788  name   1   0
# 3     19  1  57    0  0.160      22  5.750    18  2.250  0.571  name   1   0
# 4     26  0  68    0  0.260       5  4.310    12      1  0.857  name   1   0
# ..   ... ..  ..  ...    ...     ...    ...   ...    ...    ...   ...  ..  ..
# 125  7.5  1  64    0   0.24    12.9   4.72    12      1  0.857  name   ?   ?
# 126   41  0  64    0   0.28    5.40   5.47    11   1.10  0.714  name   ?   ?
# 127   36  0  69    0   0.20    7.00   5.05  14.5   1.21  0.857  name   ?   ?
# 128   22  0  57    0   0.14    16.1   4.36    15   1.36  0.786  name   ?   ?
# 129   20  0  62    0   0.15       0   4.51  15.5  1.409  0.786  name   ?   ?
#
# [130 rows x 13 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   11      130 non-null    object
#  1   0       130 non-null    int64
#  2   71      130 non-null    object
#  3   0.1     130 non-null    int64
#  4   0.260   130 non-null    object
#  5   9       130 non-null    object
#  6   4.600   130 non-null    object
#  7   14      130 non-null    object
#  8   1       130 non-null    object
#  9   1.1     130 non-null    object
#  10  name    130 non-null    object
#  11  1.2     130 non-null    object
#  12  0.2     130 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 13.3+ KB

# %%
#Los valores faltantas se represetan con una ?
#Para representarlos correctamente seran reemplazados con NaN
#Reemplazar los valores representados como "?" con NaN
dataframe = dataframe.replace("?", np.nan)

# Mostrar el DataFrame resultante
print(dataframe)
# Out:
#       11  0  71  0.1  0.260       9  4.600    14      1    1.1  name  1.2  0.2
# 0     19  0  72    0  0.380       6  4.100    14  1.700  0.588  name    1    0
# 1     16  0  55    0  0.260       4  3.420    14      1      1  name    1    0
# 2     57  0  60    0  0.253  12.062  4.603    16  1.450  0.788  name    1    0
# 3     19  1  57    0  0.160      22  5.750    18  2.250  0.571  name    1    0
# 4     26  0  68    0  0.260       5  4.310    12      1  0.857  name    1    0
# ..   ... ..  ..  ...    ...     ...    ...   ...    ...    ...   ...  ...  ...
# 125  7.5  1  64    0   0.24    12.9   4.72    12      1  0.857  name  NaN  NaN
# 126   41  0  64    0   0.28    5.40   5.47    11   1.10  0.714  name  NaN  NaN
# 127   36  0  69    0   0.20    7.00   5.05  14.5   1.21  0.857  name  NaN  NaN
# 128   22  0  57    0   0.14    16.1   4.36    15   1.36  0.786  name  NaN  NaN
# 129   20  0  62    0   0.15       0   4.51  15.5  1.409  0.786  name  NaN  NaN
#
# [130 rows x 13 columns]

# %% [markdown]
# (b) Assign the attributes with meaningful names. You can look for this information on the same
# webpage.

# %%
#Los nombres significativos se encuentran en el archivo echocardiogram.names
attribute_names = [
    'survival',
    'still-alive',
    'age-at-heart-attack',
    'pericardial-effusion',
    'fractional-shortening',
    'epss',
    'lvdd',
    'wall-motion-score',
    'wall-motion-index',
    'mult',
    'name',
    'group',
    'alive-at-1'
]

# %%
#Reemplazar los valores de cada columna con sus respectivos nombres significativos segun la informacion en el archivo .name
dataframe.columns = attribute_names
dataframe
# Out:
#     survival  still-alive age-at-heart-attack  pericardial-effusion  \
# 0         19            0                  72                     0
# 1         16            0                  55                     0
# 2         57            0                  60                     0
# 3         19            1                  57                     0
# 4         26            0                  68                     0
# ..       ...          ...                 ...                   ...
# 125      7.5            1                  64                     0
# 126       41            0                  64                     0
# 127       36            0                  69                     0
# 128       22            0                  57                     0
# 129       20            0                  62                     0
#
#     fractional-shortening    epss   lvdd wall-motion-score wall-motion-index  \
# ...

# %% [markdown]
# (c) According to that same information, is there any redundant or irrelevant attribute that you can
# remove? Remove them.

# %%
#Asiendo un analisis a los datos, se identifica que existen 3 columnas que no son relevantes o aportan alguna informacion imporante
#Se eliminan las columnas de "name", "group", "mult" y "alive-at-1"
dataframe = dataframe.drop('name', axis=1)
dataframe = dataframe.drop('group', axis=1)
dataframe = dataframe.drop('mult', axis=1)
dataframe = dataframe.drop('alive-at-1', axis=1)
dataframe
# Out:
#     survival  still-alive age-at-heart-attack  pericardial-effusion  \
# 0         19            0                  72                     0
# 1         16            0                  55                     0
# 2         57            0                  60                     0
# 3         19            1                  57                     0
# 4         26            0                  68                     0
# ..       ...          ...                 ...                   ...
# 125      7.5            1                  64                     0
# 126       41            0                  64                     0
# 127       36            0                  69                     0
# 128       22            0                  57                     0
# 129       20            0                  62                     0
#
#     fractional-shortening    epss   lvdd wall-motion-score wall-motion-index
# ...

# %% [markdown]
# (d) Is there any data type change that you find useful? Perform it.

# %%
#Cambiar las columnas "still-alive" y "pericardial-effusion" a booleano para reducir los recursos de procesamiento de datos
dataframe['still-alive'] = dataframe['still-alive'].astype(bool)
dataframe['pericardial-effusion'] = dataframe['pericardial-effusion'].astype(bool)

# %%
dataframe
# Out:
#     survival  still-alive age-at-heart-attack  pericardial-effusion  \
# 0         19        False                  72                 False
# 1         16        False                  55                 False
# 2         57        False                  60                 False
# 3         19         True                  57                 False
# 4         26        False                  68                 False
# ..       ...          ...                 ...                   ...
# 125      7.5         True                  64                 False
# 126       41        False                  64                 False
# 127       36        False                  69                 False
# 128       22        False                  57                 False
# 129       20        False                  62                 False
#
#     fractional-shortening    epss   lvdd wall-motion-score wall-motion-index
# ...
